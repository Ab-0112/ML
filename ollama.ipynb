# %%
import requests
import json

url = "http://localhost:11434/api/generate"

data = {
    "model": "llama3.2",
    "prompt": "tell about the dteails of tirupati.",
}

response = requests.post(
    url, json=data, stream=True
)  # remove the stream=True to get the full response


# check the response status
if response.status_code == 200:
    print("Generated Text:", end=" ", flush=True)
    # Iterate over the streaming response
    for line in response.iter_lines():
        if line:
            # Decode the line and parse the JSON
            decoded_line = line.decode("utf-8")
            result = json.loads(decoded_line)
            # Get the text from the response
            generated_text = result.get("response", "")
            print(generated_text, end="", flush=True)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Generated Text: Tirumala is a sacred town in the Chittoor district of Andhra Pradesh, India. It is one of the most revered pilgrimage sites for Hindus, and is known as the "Abode of Lord Venkateswara." Here are some details about Tirumala:
#
# **History**
#
# Tirumala has a rich history dating back to the 7th century AD, when it was a major center of Buddhist and Jainism. In 990 AD, the Chola dynasty built a temple complex on the hills, which was later destroyed by the Kakatiya dynasty. The present-day Sri Venkateswara Temple was built in 1596 by the Achyuta Raya, a noble of the kingdom.
#
# **The Temple**
#
# The main temple in Tirumala is the Sri Venkateswara Temple, also known as the Govindaraja Swamy Temple. It is dedicated to Lord Venkateswara, an incarnation of Lord Vishnu. The temple is famous for its intricate carvings and sculptures, which depict various deities and mythological scenes.
#
# **The Hills**
#
# Tirumala is situated on the Western Ghats mountain range, at an elevation of 1,800 feet (550 meters) above sea level. The hills are covered in dense forests of teak, eucalyptus, and other trees. The climate is temperate, with mild winters and hot summers.
#
# **The Legend of Tirumala**
#
# According to legend, Lord Venkateswara was born on the hill of Tirumala after his mother, Sridevi, gave birth to him in a coconut tree. He was later married to Bhoodevi, who was also born on the hill.
#
# **The Puri Temple**
#
# In the heart of Tirumala is the sacred temple of Puri, which is located at an elevation of 1,200 feet (365 meters). The Puri Temple is smaller than the main temple but has great spiritual significance. It is said to be the spot where Lord Venkateswara took his first steps after being born.
#
# **The Annapurna Temple**
#
# Nearby the Puri Temple is the Annapurna Temple, which is dedicated to Goddess Annapurna, the goddess of food and prosperity. The temple is famous for its beautiful carvings and sculptures.
#
# **Festivals and Celebrations**
#
# Tirumala celebrates various festivals throughout the year, including:
#
# * Tirumala Balotrama (February): A 9-day festival to celebrate the birth of Lord Venkateswara.
# * Rama Navami (March): A festival to celebrate the birth of Lord Rama.
# * Ganesh Chaturthi (August): A festival to celebrate the birth of Lord Ganesha.
# * Navaratri (September-October): A 9-day festival to celebrate the divine feminine energy.
#
# **Tourist Attractions**
#
# Some popular tourist attractions in Tirumala include:
#
# * The Annamalai Temple: Dedicated to Lord Shiva.
# * The Kalyana Lakshmi Temple: Dedicated to Goddess Lakshmi, the goddess of prosperity.
# * The Thiruvidambalam Temple: A beautiful temple dedicated to Lord Murugan.
#
# **Getting There**
#
# Tirumala is accessible by road and rail. The nearest airport is Renigunta Airport, which is about 15 kilometers away from Tirumala. The town has regular bus services from major cities in Andhra Pradesh and other states.
#
# **Accommodation**
#
# There are various accommodation options available in Tirumala, ranging from budget-friendly guesthouses to luxury hotels. Some popular hotels include:
#
# * Hotel Sree Sai
# * Hotel Sri Venkateswara
# * Hotel Annamalai
# * Hotel Kalyana Lakshmi
#
# Overall, Tirumala is a sacred and revered place that offers a unique spiritual experience for pilgrims from all over the world.

# %%
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\venka\appdata\local\anaconda3\lib\site-packages (0.4.6)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from ollama) (0.27.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from ollama) (2.10.5)
# Requirement already satisfied: anyio in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\venka\appdata\local\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)

# %%
import ollama
import os

model = "llama3.2"

# Paths to input and output files
input_file = "city_list.txt"
output_file = "categorized_city_list.txt"


# Check if the input file exists
if not os.path.exists(input_file):
    print(f"Input file '{input_file}' not found.")
    exit(1)


# Read the uncategorized city items from the input file
with open(input_file, "r") as f:
    items = f.read().strip()


# Prepare the prompt for the model
prompt = f"""
You are an assistant that categorizes and sorts cities.

Here is a list of city items:

{items}

Please:

1. Categorize these cities based on the basis of population.
2. Sort the items alphabetically within each category.
3. Present the categorized list in a clear and organized manner, using bullet points or numbering.

"""


# Send the prompt and get the response
try:
    response = ollama.generate(model=model, prompt=prompt)
    generated_text = response.get("response", "")
    print("==== Categorized List: ===== \n")
    print(generated_text)

    # Write the categorized list to the output file
    with open(output_file, "w") as f:
        f.write(generated_text.strip())

    print(f"Categorized city list has been saved to '{output_file}'.")
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# ==== Categorized List: =====
#
# After categorizing and sorting the cities based on their population, here is the list:
#
# **Tier 1: Over 10 million population**
#
# • Mumbai
# • Delhi
# • Bengaluru (Bangalore)
# • Chennai
# • Hyderabad
# • Kolkata
# • Surat
#
# **Tier 2: 5-10 million population**
#
# • Ahmedabad
# • Nagpur
# • Lucknow
# • Kanpur
# • Indore
# • Ghaziabad
# • Vadodara
# • Visakhapatnam
# • Patna
# • Thane
#
# **Tier 3: 1-5 million population**
#
# • Pune
# • Jaipur
# • Bhopal
# • Pimpri-Chinchwad
# Categorized city list has been saved to 'categorized_city_list.txt'.
